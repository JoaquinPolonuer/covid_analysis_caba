# %%
import pandas as pd

# %%
casos = pd.read_csv("https://sisa.msal.gov.ar/datos/descargas/covid-19/files/Covid19Casos.csv")

# %%
caba = casos[casos["carga_provincia_nombre"]=="CABA"]

# %%
casos.clasificacion_resumen.unique()
# Out:
# array(['Descartado', 'Sospechoso', 'Confirmado', 'Sin Clasificar'],
#       dtype=object)

# %%
len(caba[caba["clasificacion_resumen"]=="Confirmado"])+len(caba[caba["clasificacion_resumen"]=="Sin Clasificar"])
# Out:
# 253819

# %%
casos.sort_values("fecha_diagnostico")
# Out:
#          id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 326075          1383222    F  51.0            Años        SIN ESPECIFICAR
# 1619174         2818673    M  14.0            Años              Argentina
# 283499          1333926    F  17.0            Años              Argentina
# 1824083         3038593    M   9.0            Años        SIN ESPECIFICAR
# 1926172         3147945    F  24.0            Años              Argentina
# ...                 ...  ...   ...             ...                    ...
# 3194566          999746    F  34.0            Años              Argentina
# 3194593          999784    M  28.0            Años              Argentina
# 3194603          999800    F  20.0            Años              Argentina
# 3194662          999873    F  74.0            Años              Argentina
# 3194670          999883    M   2.0            Años        SIN ESPECIFICAR
#
#         residencia_provincia_nombre residencia_departamento_nombre  \
# ...
